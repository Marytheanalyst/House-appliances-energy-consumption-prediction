# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv(r"C:\Users\GODFREY\Downloads\energy_data.csv")

# %%
data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9  T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53   6.60        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56   6.48        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50   6.37        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40   6.25        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40   6.13        733.9
#
# ...

# %%
data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
data.shape
# Out:
# (19735, 29)

# %%
data.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
mydata = data.drop(["rv1", "rv2", "date", "lights"], axis = 1)

# %%
mydata.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...    T8       RH_8         T9   RH_9  T_out  \
# 0  45.566667  17.166667  ...  18.2  48.900000  17.033333  45.53   6.60
# 1  45.992500  17.166667  ...  18.2  48.863333  17.066667  45.56   6.48
# 2  45.890000  17.166667  ...  18.2  48.730000  17.000000  45.50   6.37
# 3  45.723333  17.166667  ...  18.1  48.590000  17.000000  45.40   6.25
# 4  45.530000  17.200000  ...  18.1  48.590000  17.000000  45.40   6.13
#
#    Press_mm_hg  RH_out  Windspeed  Visibility  Tdewpoint
# ...

# %%
mydata.corr()
# Out:
#              Appliances        T1      RH_1        T2      RH_2        T3  \
# Appliances     1.000000  0.055447  0.086031  0.120073 -0.060465  0.085060
# T1             0.055447  1.000000  0.164006  0.836834 -0.002509  0.892402
# RH_1           0.086031  0.164006  1.000000  0.269839  0.797535  0.253230
# T2             0.120073  0.836834  0.269839  1.000000 -0.165610  0.735245
# RH_2          -0.060465 -0.002509  0.797535 -0.165610  1.000000  0.137319
# T3             0.085060  0.892402  0.253230  0.735245  0.137319  1.000000
# RH_3           0.036292 -0.028550  0.844677  0.121497  0.678326 -0.011234
# T4             0.040281  0.877001  0.106180  0.762066 -0.047304  0.852778
# RH_4           0.016965  0.097861  0.880359  0.231563  0.721435  0.122737
# T5             0.019760  0.885247  0.205797  0.720550  0.110409  0.888169
# RH_5           0.006955 -0.014782  0.303258  0.029595  0.250271 -0.066355
# T6             0.117638  0.654769  0.316141  0.801186 -0.009670  0.686882
# ...

# %%
X = mydata['T2'].values.reshape(-1, 1)
y = mydata['T6'].values

model = LinearRegression()
model.fit(X, y)

r2 = model.score(X, y)

print("R-squared value:", round(r2, 2))
# Out:
# R-squared value: 0.64

# %%
scaler = MinMaxScaler()
new_data = pd.DataFrame(scaler.fit_transform(mydata), columns = mydata.columns)
new_data.head()
# Out:
#    Appliances       T1      RH_1        T2      RH_2        T3      RH_3  \
# 0    0.046729  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066
# 1    0.046729  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871
# 2    0.037383  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569
# 3    0.037383  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685
# 4    0.046729  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685
#
#          T4      RH_4        T5  ...        T8      RH_8        T9      RH_9  \
# 0  0.351351  0.764262  0.175506  ...  0.173329  0.661412  0.223032  0.677290
# 1  0.351351  0.782437  0.175506  ...  0.173329  0.660155  0.226500  0.678532
# 2  0.344745  0.778062  0.175506  ...  0.173329  0.655586  0.219563  0.676049
# 3  0.341441  0.770949  0.175506  ...  0.164175  0.650788  0.219563  0.671909
# 4  0.341441  0.762697  0.178691  ...  0.164175  0.650788  0.219563  0.671909
#
# ...

# %%
X = new_data.drop("Appliances", axis = 1)
Y = new_data["Appliances"]

# %%
print(X.head())
print(Y.head())
# Out:
#         T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
#
#        RH_4        T5      RH_5  ...        T8      RH_8        T9      RH_9  \
# 0  0.764262  0.175506  0.381691  ...  0.173329  0.661412  0.223032  0.677290
# 1  0.782437  0.175506  0.381691  ...  0.173329  0.660155  0.226500  0.678532
# 2  0.778062  0.175506  0.380037  ...  0.173329  0.655586  0.219563  0.676049
# 3  0.770949  0.175506  0.380037  ...  0.164175  0.650788  0.219563  0.671909
# 4  0.762697  0.178691  0.380037  ...  0.164175  0.650788  0.219563  0.671909
#
#       T_out  Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predicted_data = model.predict(x_test)
predicted_data
# Out:
# array([0.03318658, 0.24416073, 0.034772  , ..., 0.06799452, 0.0998283 ,
#        0.05807734])

# %%
# RSS
rss = np.sum(np.square(y_test - predicted_data))
round(rss, 2)
# Out:
# 45.33

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_data)
round(mae, 3)
# Out:
# 0.05

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_data))
round(rmse, 3)
# Out:
# 0.087

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_data)
round(r2_score, 2)
# Out:
# 0.15

# %%
def get_weights_df(model, feat, col_name):

  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ['Features', col_name]
  weights_df[col_name].round(3)
  return weights_df

linear_model_weights = get_weights_df(model, x_train, 'Linear_Model_Weight')
linear_model_weights
# Out:
#        Features  Linear_Model_Weight
# 0          RH_2            -0.456553
# 1         T_out            -0.321847
# 2            T2            -0.236077
# 3            T9            -0.189903
# 4          RH_8            -0.157566
# 5        RH_out            -0.077650
# 6          RH_7            -0.044571
# 7          RH_9            -0.039887
# 8            T5            -0.015712
# 9            T1            -0.003301
# 10  Press_mm_hg             0.006845
# 11           T7             0.010401
# 12   Visibility             0.012288
# 13         RH_5             0.015947
# 14         RH_4             0.026414
# 15           T4             0.029041
# 16    Windspeed             0.029187
# 17         RH_6             0.038067
# 18         RH_3             0.096035
# 19           T8             0.101945
# 20    Tdewpoint             0.117757
# 21           T6             0.236389
# 22           T3             0.290531
# 23         RH_1             0.553471

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)
predicted_data = ridge_model.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, predicted_data))
rmse
# Out:
# 0.08751972889376865

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)
feature_weights = lasso_model.coef_

non_zero_features = sum(feature_weights != 0)
print("Number of features with non-zero weights:", non_zero_features)
# Out:
# Number of features with non-zero weights: 4

# %%
predicted_data = lasso_model.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, predicted_data))
print("RMSE with Lasso regression:", round(rmse, 3))
# Out:
# RMSE with Lasso regression: 0.094
